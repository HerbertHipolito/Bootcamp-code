# %%
# !pip install opencv-python
# !pip install mahotas
from skimage import segmentation
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import cv2
from skimage import data, color
from skimage.filters import threshold_otsu
import mahotas
import argparse
import os
from random import randint
from random import seed
from skimage.measure import label, regionprops, regionprops_table, shannon_entropy
from PIL import Image as im
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.7/dist-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from opencv-python) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mahotas
#   Downloading mahotas-1.4.13-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (5.7 MB)
#      |████████████████████████████████| 5.7 MB 4.5 MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from mahotas) (1.21.6)
# Installing collected packages: mahotas
# Successfully installed mahotas-1.4.13

# %% [markdown]
# https://scikit-image.org/docs/stable/auto_examples/segmentation/plot_regionprops.html
#
# https://jni.github.io/i2k-skimage-napari/lectures/2_segmentation_and_regionprops.html

# %% [markdown]
# #Class and functions used

# %% [markdown]
# ##functions

# %%
def display_multi_img(images,rows,columns,F_size=(15,8),title=None,show_axis=False):
  
  fig = plt.figure(figsize=F_size)
  #fig,ax=plt.subplots(figsize=(8,10))
  for i in range(rows):
    for j in range(columns):
      fig.add_subplot(rows,columns,i*columns+j+1)
      plt.imshow(images[i][j])
      plt.axis('off')


def display_img(image,title='Image',x_label=None,y_label=None,cmap_type='gray',show_axis=False,colorBar=False,F_size=(8,6)):
  plt.figure(figsize=F_size)
  plt.imshow(image,cmap=cmap_type)
  plt.title(title)
  plt.xlabel(x_label)
  plt.ylabel(y_label)
  if colorBar: plt.colorbar()
  if not show_axis: plt.axis('off')
  plt.show()


def cut_image(image,w,h):

  w_half,h_half = 100,100

  return image[w_half-w:w_half+w,h_half-h:h_half+h]


def save_image(image,image_name='Choose_my_name.jpg'):

    cv2.imwrite(image_name,image)

# %% [markdown]
# ##Breno's functions

# %%
def white_to_gray(img):
    for i in range(img.shape[0]):
        for j in range(img.shape[1]):
            if img[i, j] > 253:
                img[i, j] = 253
    return img


def define_pleural_nod(img, perc=0.3):
  count = 0
  img_binary = cv2.threshold(img.copy(), 70, 255, cv2.THRESH_BINARY)[1]

  (max_x,max_y) = img.shape

  for i in range(min(max_x,max_y)):

    if img_binary[0][i] != 0: count += 1
    if img_binary[i][0] != 0: count += 1
    if img_binary[i][max_y-1] != 0: count += 1
    if img_binary[max_x-1][i] != 0: count += 1

  return count / (4 * 100) > perc


def remove_pleura(img, c_a = 50, c_b = 50):
  original_img = img
  # display_img(array_of_images_malignos[img_number])
  # 60 th
  original = cv2.threshold(original_img, 10, 255, cv2.THRESH_BINARY)[1]

  #display_img(original)

  new_color = 50
  contours, h = cv2.findContours(original.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
  (x, y) = original.shape
  # print(contours)

  image = cv2.drawContours(original.copy(), contours, -1, (new_color, 0, 0), 1)
  # print('Contorno total')
  # display_img(image)

  initial_contour = image
  partial_complement = image.copy()

  for index in range(x):

    if image[0][index] != new_color: partial_complement[0][index] = new_color
    if image[x - 1][index] != new_color: partial_complement[x - 1][index] = new_color
    if image[index][0] != new_color: partial_complement[index][0] = new_color
    if image[index][y - 1] != new_color: partial_complement[index][y - 1] = new_color

  # print('contorno parcial')
  # display_img(partial_complement)

  complement = partial_complement.copy()

  for index in range(98):

    if image[0][index] == new_color and partial_complement[0][index] == new_color: complement[0][index] = original[0][
      index]
    if image[x - 1][index] == new_color and partial_complement[0][index] == new_color: complement[x - 1][index] = \
    original[x - 1][index]
    if image[index][0] == new_color and partial_complement[0][index] == new_color: complement[index][0] = \
    original[index][0]
    if image[index][y - 1] == new_color and partial_complement[0][index] == new_color: complement[index][y - 1] = \
    original[index][y - 1]

  # print('contorno complementar')
  # display_img(complement)

  contours, h = cv2.findContours(complement.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
  # print(contours)

  # image = cv2.drawContours(complement.copy(),contours,-1,(255,0,0),1)
  # display_img(image)

  hull_list = []

  for i in range(len(contours)):
    hull = cv2.convexHull(contours[i])
    hull_list.append(hull)

  # drawing = np.zeros((complement.shape[0], complement.shape[1]), dtype=np.uint8)
  drawing = complement.copy()

  for i in range(len(contours)):
    # color = (random.randint(0,255), random.randint(0,255), random.randint(0,255))

    # cv2.drawContours(drawing, contours, i, new_color)
    cv2.drawContours(drawing, hull_list, i, new_color, lineType=cv2.LINE_4, thickness=1)

  # print('convex hull')
  # display_img(drawing)

  # print(complement.shape,drawing.shape)
  final_result = cv2.bitwise_and(initial_contour, drawing)
  # display_img(final_result)

  new_value = 30

  # display_img(final_result)
  flood_again = segmentation.flood_fill(final_result, (c_a, c_b), new_value=new_value, connectivity=1)
  # display_img(flood_again)

  nodule = original_img.copy()
  # display_img(nodule)

  for i, row in enumerate(flood_again):

    for j, pixel in enumerate(row):

      if pixel != new_value: nodule[i][j] = 0

  return nodule

def pp_good(img):
  img = white_to_gray(img)
  original = img

  gray = img[50, 50]
  (c_1, c_2) = (50, 50)
  for i in range(9):
    # Horizontal vertical
    if img[46 + i, 50] > img[50, 46 + i]:
      if img[46 + i, 50] > gray:
        (c_1, c_2) = (46 + i, 50)
        gray = img[46 + i, 50]
    else:
      if img[50, 46 + i] > gray:
        (c_1, c_2) = (50, 46 + i)
        gray = img[50, 46 + i]

  if gray < 90:
    tol = 30
  else:
    tol = 90

  #print(gray)
  #print((c_1, c_2))

  img = cv2.GaussianBlur(img, (3,3), 0)
  #show_img("Img_Gau", img)
  img = segmentation.flood_fill(img, (c_1, c_2), 255, tolerance = tol)
  #show_img("Img_seg", img)
  img_pp = cv2.threshold(img, 254, 255, cv2.THRESH_TOZERO)[1]
  #show_img("Img_tre", img)
  # Passando a mascara
  img_pp = cv2.bitwise_and(original,original,mask = img_pp)

  if define_pleural_nod(img_pp):
    img_pp = remove_pleura(img_pp, c_1, c_2)
  return img_pp

# %% [markdown]
# ##Classes

# %%
class pre_processing:

  def __init__(self,image,to_gray = False):

    if to_gray:
      self.image = cv2.cvtColor(image.copy(), cv2.COLOR_BGR2GRAY)
    else:
      self.image = image.copy()

    self.original_image = image.copy()
    self.pipeline = dict()
  
  def color_bgr_to_gray(self):

    self.image = cv2.cvtColor(self.image, cv2.COLOR_BGR2GRAY)
  
  def gaussian_blur(self,size=(11,11)):

    if size[0]%2==0 or size[1]%2==0: raise Exception('The heigh and width must be odd');
    self.image = cv2.GaussianBlur(self.image, size, 0)
    
    self.pipeline[self.gaussian_blur.__name__] = {'size':size}

  def cut_image(self,w,h):

    (w_total,h_total) = self.image.shape

    w_half,h_half = 100,100

    self.image = self.image[w_half-w:w_half+w,h_half-h:h_half+h]

  def find_contours(self,line_thickness = 1,mode = cv2.RETR_TREE,method = cv2.CHAIN_APPROX_SIMPLE,show_contours_order = -1):

    contours, hierarchy = cv2.findContours(self.image,mode,method)
    self.contours = contours
    self.image = cv2.drawContours(self.original_image,contours,show_contours_order,(0,255,0),line_thickness)

    self.pipeline[self.find_contours.__name__] = {'line_thickness':line_thickness,'mode':mode,'method':method,'show_contours_order':show_contours_order}

  def flood_fill(self,seed_point = (20,20),new_value = 0,tolerance=100):

    self.image = segmentation.flood_fill(self.image,seed_point,new_value,tolerance=tolerance)

    self.pipeline[self.flood_fill.__name__] = {'seed_point':seed_point,'tolerance':tolerance,'new_value':new_value}
  
  def flood_fill_2(self,xy,newColor,lowDiff,upDiff):

    size = self.image.shape
    mask = np.zeros((size[0]+2,size[1]+2),np.uint8)
    _,self.image,_,_ = cv2.floodFill(self.image, mask, xy,newColor,lowDiff,upDiff)
    #im_floodfill_inv = cv2.bitwise_not(self.image)
    #im_out = self.image & im_floodfill_inv

    #self.image = im_out
  
  def propagation(self,threshold_used=254):

    image_modified = []

    for i,key_i in enumerate(self.image):
      row = []
      for j,key_j in enumerate(self.image[i]):
        row.append(self.original_image[i][j][0]) if key_j > threshold_used else row.append(self.image[i][j])
      
      image_modified.append(row)

    return image_modified

  def fixed_threshold(self,threshold=70,pixel=255,threshold_binary=False,threshold_zero=False):
    
    if threshold_zero:
      self.image = cv2.threshold(self.image, threshold, pixel, cv2.THRESH_TOZERO)[1]
    else:
      if threshold_binary:
        self.image = cv2.threshold(self.image, threshold, pixel, cv2.THRESH_BINARY)[1]
      else:  
        self.image = cv2.threshold(self.image, threshold, pixel, cv2.THRESH_BINARY_INV )[1]
      
    self.pipeline[self.fixed_threshold.__name__] = {'threshold':threshold,'pixel':pixel,'threshold_binary':threshold_binary,'threshold_zero':threshold_zero}

  def multi_threshold(self,initial_thresholds,final_thresholds,thresh_binary=True,qtd_columns=2,step=5,pixel=255):

    [matrix_of_thresholds,thresholds] = [[],initial_thresholds]

    while(True):

      row = []

      for index in range(qtd_columns):
        
        row.append(cv2.threshold(self.image, thresholds, 255, cv2.THRESH_BINARY)[1])
        row.append(cv2.threshold(self.image, thresholds, 255, cv2.THRESH_BINARY_INV)[1])
        
        thresholds+=step

      matrix_of_thresholds.append(np.hstack(row))
      if thresholds>=final_thresholds: break

    result = np.vstack(matrix_of_thresholds)
    self.display_img(result,size=(18,28))

  def adaptative_threshold(self,block_size=25,thresh_mean = True,thresh_binary_inv=True,number_to_decrease=7,pixel=255):
    
    if thresh_mean:
      if thresh_binary_inv:
        self.image = cv2.adaptiveThreshold(self.image,pixel,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY_INV,block_size,number_to_decrease)
      else:
        self.image = cv2.adaptiveThreshold(self.image,pixel,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,block_size,number_to_decrease)
    else:
      if thresh_binary_inv:
        self.image = cv2.adaptiveThreshold(self.image,pixel,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY_INV,block_size,number_to_decrease)
      else:
        self.image = cv2.adaptiveThreshold(self.image,pixel,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,block_size,number_to_decrease)
      
    self.pipeline[self.adaptative_threshold.__name__] = {'block_size':block_size,'thresh_mean':True,'thresh_binary_inv':True,'number_to_decrease':number_to_decrease,'pixel':pixel}

  def sobel(self,typeCV = cv2.CV_64F):

      sobelX = cv2.Sobel(self.image, typeCV, 1, 0) 
      sobelX = np.uint8(np.absolute(sobelX))
      sobelY = cv2.Sobel(self.image, typeCV, 0, 1)
      sobelY = np.uint8(np.absolute(sobelY))
      sobel = cv2.bitwise_or(sobelX, sobelY)
    
      self.image = sobel

      self.pipeline[self.sobel.__name__] = {}
  
  def laplacian_filter(self,threshold=60):

    lap = cv2.Laplacian(self.image, cv2.CV_64F) 
    lap = np.uint8(np.absolute(lap)) 
    self.image = lap

    self.pipeline[self.laplacian_filter.__name__] = {'threshold':threshold}
  
  def canny(self, T_lower=15,T_upper=120):
    
    self.image = cv2.Canny(self.image, T_lower, T_upper)
    
    self.pipeline[self.canny.__name__] = {'T_lower':T_lower,'T_upper':T_upper}

  def equalize_image(self):

    self.image = cv2.equalizeHist(self.image)

    self.pipeline[self.equalize_image.__name__] = {}

  def connectComponents(self,min_h,max_h,min_w,max_w):

    output = cv2.connectedComponentsWithStats(self.image, 4, cv2.CV_32S)

    (numLabels, labels, stats, centroids) = output
    [matrix_of_slice,matrix_of_result,matrix_of_mask] = [[],[],[]]

    for i in range(0,numLabels):
      
      if i is not 0:
        
        print('infor examining component {}/{}'.format(i,numLabels-1))
        x = stats[i,cv2.CC_STAT_LEFT]
        y = stats[i,cv2.CC_STAT_TOP]
        w = stats[i,cv2.CC_STAT_WIDTH]
        h = stats[i,cv2.CC_STAT_HEIGHT]
        area = stats[i,cv2.CC_STAT_AREA]
        (cX,cY) = centroids[i]
        result = self.original_image.copy()
  
        image_slice = result[x:x + w + 5,y:y + h+ 5]

        keepWidth = w > min_w and w < max_w
        keepHeight = h > min_h and h < max_h
  
        if all((keepWidth, keepHeight)):
          
          print('selected')
          matrix_of_slice.append(image_slice)
          matrix_of_result.append(result)
          cv2.rectangle(result, (x, y), (x + w, y + h), (0, 255, 0), 3)
          cv2.circle(result, (int(cX), int(cY)), 4, (0, 0, 255), -1)
          componentMask = (labels == i).astype("uint8") * 255
      
    return [matrix_of_slice,matrix_of_result],len(matrix_of_result)

  def get_image(self):

    return self.image
  
  def save_image(self,image_name='Choose_my_name.jpg'):

    cv2.imwrite(image_name,self.image)

  def display_img(self,title='Image',x_label=None,y_label=None,cmap_type='gray',show_axis=False,colorBar=False,size=(8,6)):
    plt.figure(figsize=size)
    plt.imshow(self.image,cmap=cmap_type)
    plt.title(title)
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    if colorBar: plt.colorbar()
    if not show_axis: plt.axis('off')
    plt.show()

# %% [markdown]
# #Loading data

# %% [markdown]
# #Loading all nodule images
#
# All data are loaded from Google Drive. However, if you choose to select some of them randomly, you may get an error once there are a few images of different sizes.

# %%
select_images_randomly = False

directory_path_malignos = '/content/drive/MyDrive/all_nods_malignos_converted/'
directory_path_benignos = '/content/drive/MyDrive/all_nods_benignos_converted/'

directory_files_malignos = os.listdir(directory_path_malignos)
array_of_images_malignos = [plt.imread( os.path.join(directory_path_malignos,file) ) for file in directory_files_malignos]
array_of_images_malignos_200 = [plt.imread( os.path.join(directory_path_malignos,file) ) for file in directory_files_malignos if plt.imread(os.path.join(directory_path_malignos,file)).shape[0] == 200 and plt.imread(os.path.join(directory_path_malignos,file)).shape[1] == 200]

directory_files = os.listdir(directory_path_benignos)
array_of_images_benignos = [plt.imread( os.path.join(directory_path_benignos,file) ) for file in directory_files]
array_of_images_benignos_200 = [plt.imread( os.path.join(directory_path_benignos,file) ) for file in directory_files if plt.imread( os.path.join(directory_path_benignos,file) ).shape[0] == 200 and plt.imread( os.path.join(directory_path_benignos,file) ).shape[1] == 200]

print(f'Number of maligno images: {len(array_of_images_malignos)}')
print(f'Number of benigno images: {len(array_of_images_benignos)}')
print(f'Number of maligno images with size 200x200: {len(array_of_images_malignos_200)}')
print(f'Number of benigno images with size 200x200: {len(array_of_images_benignos_200)}')

if select_images_randomly:

  index_benigno1,index_benigno2 = randint(0,len(array_of_images_benignos_200)-1),randint(0,len(array_of_images_benignos_200)-1)
  index_maligno1,index_maligno2 = randint(0,len(array_of_images_malignos_200)-1),randint(0,len(array_of_images_malignos_200)-1)
  print(index_benigno1,index_benigno2,index_maligno1,index_maligno2)
  [benigno1,benigno2] = [array_of_images_benignos_200[index_benigno1],array_of_images_benignos_200[index_benigno2]]
  [maligno1,maligno2] = [array_of_images_malignos_200[index_maligno1],array_of_images_malignos_200[index_maligno2]]

else:

  index_benigno1,index_benigno2 = 2,3
  index_maligno1,index_maligno2 = 10,16
  [benigno1,benigno2] = [array_of_images_benignos[index_benigno1],array_of_images_benignos[index_benigno2]]
  [maligno1,maligno2] = [array_of_images_malignos[index_maligno1],array_of_images_malignos[index_maligno2]]

print(benigno1.shape,benigno2.shape,maligno1.shape,maligno2.shape)

four_images = np.vstack([  np.hstack([benigno1, benigno2]),  np.hstack([maligno1, maligno2])  ])
display_img(four_images,F_size=(11,11))

tumor_picture = four_images
# Out:
# Number of maligno images: 262
# Number of benigno images: 275
# Number of maligno images with size 200x200: 242
# Number of benigno images with size 200x200: 241
# (200, 200, 3) (200, 200, 3) (200, 200, 3) (200, 200, 3)

# %% [markdown]
# ##Getting all cropped images

# %%
[cropped_benigno_images,cropped_maligno_images] = [[],[]]

if select_images_randomly:
  cropped_benigno_images = [cut_image(image,49,49) for image in array_of_images_benignos]
  cropped_maligno_images = [cut_image(image,49,49) for image in array_of_images_malignos]
else:
  cropped_benigno_images = [cut_image(image,49,49) for image in array_of_images_benignos]
  cropped_maligno_images = [cut_image(image,49,49) for image in array_of_images_malignos]

[benigno1,benigno2] = [cropped_benigno_images[index_benigno1],cropped_benigno_images[index_benigno2]]
[maligno1,maligno2] = [cropped_maligno_images[index_maligno1],cropped_maligno_images[index_maligno2]]

print(benigno1.shape,benigno2.shape,maligno1.shape,maligno2.shape)
print(f'Number of benigno images: {len(cropped_benigno_images)}')
print(f'Number of maligno images: {len(cropped_maligno_images)}')

four_images = np.vstack([  np.hstack([benigno1, benigno2]),  np.hstack([maligno1, maligno2])  ])
display_img(four_images,F_size=(11,11))

cv2.imwrite('flood fill aplicando em nodulos recortados original.png',four_images)
tumor_picture = four_images
# Out:
# (98, 98, 3) (98, 98, 3) (98, 98, 3) (98, 98, 3)
# Number of benigno images: 275
# Number of maligno images: 262

# %% [markdown]
# #Pipelines

# %% [markdown]
# ## threshold

# %%
title = ''

pipeline1 = pre_processing(tumor_picture,to_gray=True)
pipeline1.fixed_threshold(70,threshold_binary=False,threshold_zero=True)

for name in pipeline1.pipeline.keys():title += ' '+name

pipeline1.display_img(title=title,size=(10,10))
#pipeline1.save_image(title+'.png')
print(pipeline1.pipeline)
# Out:
# {'fixed_threshold': {'threshold': 70, 'pixel': 255, 'threshold_binary': False, 'threshold_zero': True}}

# %% [markdown]
# ##Blur + Fixed Threshold + Sobel
#
# Explanation: In this pipeline, I was trying to figure out a way to highlight the nodule border, remove image noises and increase the difference between that border and the image remaining. As you can see below, all the border was really emphasized and noises removed, making it easier to detect the nodules.

# %%
title = ''
pipeline2 = pre_processing(tumor_picture,to_gray=True)
pipeline2.gaussian_blur((11,11))
pipeline2.fixed_threshold(60)
pipeline2.sobel()

for name in pipeline2.pipeline.keys(): title += ' '+name

pipeline2.display_img(title=title,size=(13,13))
pipeline2.save_image(title+'.png')
print(pipeline2.pipeline)
# Out:
# {'gaussian_blur': {'size': (11, 11)}, 'fixed_threshold': {'threshold': 60, 'pixel': 255, 'threshold_binary': False, 'threshold_zero': False}, 'sobel': {}}

# %% [markdown]
# ##Blur + Canny

# %%
title = ''

pipeline6 = pre_processing(tumor_picture,to_gray=True)
pipeline6.gaussian_blur()
pipeline6.canny(15,150)

for name in pipeline6.pipeline.keys():title += ' '+name
pipeline6.display_img(title=title,size=(13,13))
#pipeline6.save_image(title+'.png')

print(pipeline6.pipeline)
# Out:
# {'gaussian_blur': {'size': (11, 11)}, 'canny': {'T_lower': 15, 'T_upper': 150}}

# %% [markdown]
# ## Flood fill

# %% [markdown]
# ###Applying flood fill in the 4 images selected

# %%
title = ''

pipeline6 = pre_processing(tumor_picture,to_gray=True)
pipeline6.flood_fill((int(tumor_picture.shape[0]*3/4),int(tumor_picture.shape[1]*3/4)),255,tolerance=60)
pipeline6.flood_fill((int(tumor_picture.shape[0]*1/4),int(tumor_picture.shape[1]*1/4)),255,tolerance=60)
pipeline6.flood_fill((int(tumor_picture.shape[0]*3/4),int(tumor_picture.shape[1]*1/4)),255,tolerance=60)
pipeline6.flood_fill((int(tumor_picture.shape[0]*1/4),int(tumor_picture.shape[1]*3/4)),255,tolerance=60)

pipeline6.fixed_threshold(254,threshold_zero=True)

image_modified = pipeline6.image.copy()

for name in pipeline6.pipeline.keys():title += ' '+name
pipeline6.display_img(title=title,size=(10,10))

print(pipeline6.pipeline)

new_image = []

for i,key_i in enumerate(pipeline6.image):
  for j,key_j in enumerate(pipeline6.image[i]):

    if key_j > 254:
      image_modified[i][j] = pipeline6.original_image[i][j][0]
    else:
      image_modified[i][j] = pipeline6.image[i][j]

cv2.imwrite('flood fill aplicando em nodulos recortados.png',image_modified)
display_img(image_modified,F_size=(10,10))
# Out:
# {'flood_fill': {'seed_point': (22, 66), 'tolerance': 60, 'new_value': 255}, 'fixed_threshold': {'threshold': 254, 'pixel': 255, 'threshold_binary': False, 'threshold_zero': True}}

# %% [markdown]
# ###Applying flood fill in an image

# %%
title = ''
test_img = cropped_benigno_images[1]
display_img(test_img)
pipeline_benigno1 = pre_processing(test_img,to_gray=True)
pipeline_benigno1.gaussian_blur((3,3))
pipeline_benigno1.flood_fill((int(test_img.shape[0]/2),int(test_img.shape[1]/2)),255,tolerance=30)
pipeline_benigno1.fixed_threshold(254,threshold_zero=True)

for name in pipeline_benigno1.pipeline.keys():title += ' '+name

image_modified = pipeline_benigno1.image

print(pipeline_benigno1.pipeline)

pipeline_benigno1.propagation(254)

display_img(image_modified)
# Out:
# {'gaussian_blur': {'size': (3, 3)}, 'flood_fill': {'seed_point': (50, 50), 'tolerance': 30, 'new_value': 255}, 'fixed_threshold': {'threshold': 254, 'pixel': 255, 'threshold_binary': False, 'threshold_zero': True}}

# %% [markdown]
# #morphological operations and contours

# %% [markdown]
# ###morphological operations
#
# I still need to create a method in my class to add that algorithm.

# %%
result = cv2.getStructuringElement(cv2.MORPH_ELLIPSE,(2,2))
image = cv2.erode(benigno1,result,iterations=1)
display_img(image)

# %% [markdown]
# ###Find contours

# %%
image_modified_find = cv2.cvtColor(image_modified, cv2.COLOR_GRAY2BGR)
pipeline7 = pre_processing(image_modified_find,to_gray=True)
#pipeline7.fixed_threshold(110)
pipeline7.display_img(size=(8,8))
pipeline7.find_contours(show_contours_order=0)
pipeline7.display_img(size=(8,8))

print(pipeline7.pipeline)
print(len(pipeline7.contours))

countours_sizes = [countour.size for countour in pipeline7.contours]

print(f'The size of the nodule countour is {max(countours_sizes)}')
# Out:
# {'find_contours': {'line_thickness': 1, 'mode': 3, 'method': 2, 'show_contours_order': 0}}
# 1
# The size of the nodule countour is 90

# %% [markdown]
# #Creating new dataset based on the filters used above

# %% [markdown]
# ##Storing all cropped imagens

# %%
paths = ['/content/drive/MyDrive/cropped_nods_benigno/','/content/drive/MyDrive/cropped_nods_maligno/','/content/drive/MyDrive/cropped_nods_200_benigno/','/content/drive/MyDrive/cropped_nods_200_maligno/']

arrays = [array_of_images_benignos,array_of_images_malignos,array_of_images_benignos_200,array_of_images_malignos_200]

for i in range(len(paths)):
  count=0
  os.chdir(paths[i])
  cropped_images = [cut_image(image,20,20) for image in arrays[i]]
  for image in cropped_images:
    save_image(image,image_name=str(count)+'.jpg')
    count+=1

# %% [markdown]
# ## Treating and storing all imagens

# %%
#treating and storing the cropped images

all_cropped_images = [cropped_benigno_images,cropped_maligno_images]
results = [[],[]]
paths = ['/content/drive/MyDrive/BootcampFinal/cropped_and_treated_100_nods_benigno/','/content/drive/MyDrive/BootcampFinal/cropped_and_treated_100_nods_maligno/']
group_name = ['benigno','maligno']

for index,group in enumerate(all_cropped_images):
  
  count = 0
  for uni in group:
    
    os.chdir(paths[index])
    #pipe = pre_processing(uni.copy(),to_gray=True)
    #(c1,c2) =  pp_good(pipe.image.copy())
    #pipe.flood_fill((c1,c2),255,tolerance=80)
    #pipe.fixed_threshold(254,threshold_zero=True)
    #result = pipe.propagation(254)
    img = cv2.cvtColor(uni.copy(), cv2.COLOR_BGR2GRAY)
    result = pp_good(img)
    #display_img(result)
    print(str(count)+group_name[index]+'.png')
    #save_image(cv2.imread(result),image_name=str(count)+group_name[index]+'.png')
    cv2.imwrite(str(count)+group_name[index]+'.png',np.array(result))
    count+=1
# Out:
# 0benigno.png
# 1benigno.png
# 2benigno.png
# 3benigno.png
# 4benigno.png
# 5benigno.png
# 6benigno.png
# 7benigno.png
# 8benigno.png
# 9benigno.png
# 10benigno.png
# 11benigno.png
# 12benigno.png
# 13benigno.png
# 14benigno.png
# 15benigno.png
# 16benigno.png
# 17benigno.png
# 18benigno.png
# 19benigno.png
# 20benigno.png
# 21benigno.png
# 22benigno.png
# 23benigno.png
# 24benigno.png
# 25benigno.png
# 26benigno.png
# 27benigno.png
# 28benigno.png
# 29benigno.png
# 30benigno.png
# 31benigno.png
# 32benigno.png
# 33benigno.png
# 34benigno.png
# 35benigno.png
# 36benigno.png
# 37benigno.png
# 38benigno.png
# 39benigno.png
# 40benigno.png
# 41benigno.png
# 42benigno.png
# 43benigno.png
# 44benigno.png
# 45benigno.png
# 46benigno.png
# 47benigno.png
# 48benigno.png
# 49benigno.png
# 50benigno.png
# 51benigno.png
# 52benigno.png
# 53benigno.png
# 54benigno.png
# 55benigno.png
# 56benigno.png
# 57benigno.png
# 58benigno.png
# 59benigno.png
# 60benigno.png
# 61benigno.png
# 62benigno.png
# 63benigno.png
# 64benigno.png
# 65benigno.png
# 66benigno.png
# 67benigno.png
# 68benigno.png
# 69benigno.png
# 70benigno.png
# 71benigno.png
# 72benigno.png
# 73benigno.png
# 74benigno.png
# 75benigno.png
# 76benigno.png
# 77benigno.png
# 78benigno.png
# 79benigno.png
# 80benigno.png
# 81benigno.png
# 82benigno.png
# 83benigno.png
# 84benigno.png
# 85benigno.png
# 86benigno.png
# 87benigno.png
# 88benigno.png
# 89benigno.png
# 90benigno.png
# 91benigno.png
# 92benigno.png
# 93benigno.png
# 94benigno.png
# 95benigno.png
# 96benigno.png
# 97benigno.png
# 98benigno.png
# 99benigno.png
# 100benigno.png
# 101benigno.png
# 102benigno.png
# 103benigno.png
# 104benigno.png
# 105benigno.png
# 106benigno.png
# 107benigno.png
# 108benigno.png
# 109benigno.png
# 110benigno.png
# 111benigno.png
# 112benigno.png
# 113benigno.png
# 114benigno.png
# 115benigno.png
# 116benigno.png
# 117benigno.png
# 118benigno.png
# 119benigno.png
# 120benigno.png
# 121benigno.png
# 122benigno.png
# 123benigno.png
# 124benigno.png
# 125benigno.png
# 126benigno.png
# 127benigno.png
# 128benigno.png
# 129benigno.png
# 130benigno.png
# 131benigno.png
# 132benigno.png
# 133benigno.png
# 134benigno.png
# 135benigno.png
# 136benigno.png
# 137benigno.png
# 138benigno.png
# 139benigno.png
# 140benigno.png
# 141benigno.png
# 142benigno.png
# 143benigno.png
# 144benigno.png
# 145benigno.png
# 146benigno.png
# 147benigno.png
# 148benigno.png
# 149benigno.png
# 150benigno.png
# 151benigno.png
# 152benigno.png
# 153benigno.png
# 154benigno.png
# 155benigno.png
# 156benigno.png
# 157benigno.png
# 158benigno.png
# 159benigno.png
# 160benigno.png
# 161benigno.png
# 162benigno.png
# 163benigno.png
# 164benigno.png
# 165benigno.png
# 166benigno.png
# 167benigno.png
# 168benigno.png
# 169benigno.png
# 170benigno.png
# 171benigno.png
# 172benigno.png
# 173benigno.png
# 174benigno.png
# 175benigno.png
# 176benigno.png
# 177benigno.png
# 178benigno.png
# 179benigno.png
# 180benigno.png
# 181benigno.png
# 182benigno.png
# 183benigno.png
# 184benigno.png
# 185benigno.png
# 186benigno.png
# 187benigno.png
# 188benigno.png
# 189benigno.png
# 190benigno.png
# 191benigno.png
# 192benigno.png
# 193benigno.png
# 194benigno.png
# 195benigno.png
# 196benigno.png
# 197benigno.png
# 198benigno.png
# 199benigno.png
# 200benigno.png
# 201benigno.png
# 202benigno.png
# 203benigno.png
# 204benigno.png
# 205benigno.png
# 206benigno.png
# 207benigno.png
# 208benigno.png
# 209benigno.png
# 210benigno.png
# 211benigno.png
# 212benigno.png
# 213benigno.png
# 214benigno.png
# 215benigno.png
# 216benigno.png
# 217benigno.png
# 218benigno.png
# 219benigno.png
# 220benigno.png
# 221benigno.png
# 222benigno.png
# 223benigno.png
# 224benigno.png
# 225benigno.png
# 226benigno.png
# 227benigno.png
# 228benigno.png
# 229benigno.png
# 230benigno.png
# 231benigno.png
# 232benigno.png
# 233benigno.png
# 234benigno.png
# 235benigno.png
# 236benigno.png
# 237benigno.png
# 238benigno.png
# 239benigno.png
# 240benigno.png
# 241benigno.png
# 242benigno.png
# 243benigno.png
# 244benigno.png
# 245benigno.png
# 246benigno.png
# 247benigno.png
# 248benigno.png
# 249benigno.png
# 250benigno.png
# 251benigno.png
# 252benigno.png
# 253benigno.png
# 254benigno.png
# 255benigno.png
# 256benigno.png
# 257benigno.png
# 258benigno.png
# 259benigno.png
# 260benigno.png
# 261benigno.png
# 262benigno.png
# 263benigno.png
# 264benigno.png
# 265benigno.png
# 266benigno.png
# 267benigno.png
# 268benigno.png
# 269benigno.png
# 270benigno.png
# 271benigno.png
# 272benigno.png
# 273benigno.png
# 274benigno.png
# 0maligno.png
# 1maligno.png
# 2maligno.png
# 3maligno.png
# 4maligno.png
# 5maligno.png
# 6maligno.png
# 7maligno.png
# 8maligno.png
# 9maligno.png
# 10maligno.png
# 11maligno.png
# 12maligno.png
# 13maligno.png
# 14maligno.png
# 15maligno.png
# 16maligno.png
# 17maligno.png
# 18maligno.png
# 19maligno.png
# 20maligno.png
# 21maligno.png
# 22maligno.png
# 23maligno.png
# 24maligno.png
# 25maligno.png
# 26maligno.png
# 27maligno.png
# 28maligno.png
# 29maligno.png
# 30maligno.png
# 31maligno.png
# 32maligno.png
# 33maligno.png
# 34maligno.png
# 35maligno.png
# 36maligno.png
# 37maligno.png
# 38maligno.png
# 39maligno.png
# 40maligno.png
# 41maligno.png
# 42maligno.png
# 43maligno.png
# 44maligno.png
# 45maligno.png
# 46maligno.png
# 47maligno.png
# 48maligno.png
# 49maligno.png
# 50maligno.png
# 51maligno.png
# 52maligno.png
# 53maligno.png
# 54maligno.png
# 55maligno.png
# 56maligno.png
# 57maligno.png
# 58maligno.png
# 59maligno.png
# 60maligno.png
# 61maligno.png
# 62maligno.png
# 63maligno.png
# 64maligno.png
# 65maligno.png
# 66maligno.png
# 67maligno.png
# 68maligno.png
# 69maligno.png
# 70maligno.png
# 71maligno.png
# 72maligno.png
# 73maligno.png
# 74maligno.png
# 75maligno.png
# 76maligno.png
# 77maligno.png
# 78maligno.png
# 79maligno.png
# 80maligno.png
# 81maligno.png
# 82maligno.png
# 83maligno.png
# 84maligno.png
# 85maligno.png
# 86maligno.png
# 87maligno.png
# 88maligno.png
# 89maligno.png
# 90maligno.png
# 91maligno.png
# 92maligno.png
# 93maligno.png
# 94maligno.png
# 95maligno.png
# 96maligno.png
# 97maligno.png
# 98maligno.png
# 99maligno.png
# 100maligno.png
# 101maligno.png
# 102maligno.png
# 103maligno.png
# 104maligno.png
# 105maligno.png
# 106maligno.png
# 107maligno.png
# 108maligno.png
# 109maligno.png
# 110maligno.png
# 111maligno.png
# 112maligno.png
# 113maligno.png
# 114maligno.png
# 115maligno.png
# 116maligno.png
# 117maligno.png
# 118maligno.png
# 119maligno.png
# 120maligno.png
# 121maligno.png
# 122maligno.png
# 123maligno.png
# 124maligno.png
# 125maligno.png
# 126maligno.png
# 127maligno.png
# 128maligno.png
# 129maligno.png
# 130maligno.png
# 131maligno.png
# 132maligno.png
# 133maligno.png
# 134maligno.png
# 135maligno.png
# 136maligno.png
# 137maligno.png
# 138maligno.png
# 139maligno.png
# 140maligno.png
# 141maligno.png
# 142maligno.png
# 143maligno.png
# 144maligno.png
# 145maligno.png
# 146maligno.png
# 147maligno.png
# 148maligno.png
# 149maligno.png
# 150maligno.png
# 151maligno.png
# 152maligno.png
# 153maligno.png
# 154maligno.png
# 155maligno.png
# 156maligno.png
# 157maligno.png
# 158maligno.png
# 159maligno.png
# 160maligno.png
# 161maligno.png
# 162maligno.png
# 163maligno.png
# 164maligno.png
# 165maligno.png
# 166maligno.png
# 167maligno.png
# 168maligno.png
# 169maligno.png
# 170maligno.png
# 171maligno.png
# 172maligno.png
# 173maligno.png
# 174maligno.png
# 175maligno.png
# 176maligno.png
# 177maligno.png
# 178maligno.png
# 179maligno.png
# 180maligno.png
# 181maligno.png
# 182maligno.png
# 183maligno.png
# 184maligno.png
# 185maligno.png
# 186maligno.png
# 187maligno.png
# 188maligno.png
# 189maligno.png
# 190maligno.png
# 191maligno.png
# 192maligno.png
# 193maligno.png
# 194maligno.png
# 195maligno.png
# 196maligno.png
# 197maligno.png
# 198maligno.png
# 199maligno.png
# 200maligno.png
# 201maligno.png
# 202maligno.png
# 203maligno.png
# 204maligno.png
# 205maligno.png
# 206maligno.png
# 207maligno.png
# 208maligno.png
# 209maligno.png
# 210maligno.png
# 211maligno.png
# 212maligno.png
# 213maligno.png
# 214maligno.png
# 215maligno.png
# 216maligno.png
# 217maligno.png
# 218maligno.png
# 219maligno.png
# 220maligno.png
# 221maligno.png
# 222maligno.png
# 223maligno.png
# 224maligno.png
# 225maligno.png
# 226maligno.png
# 227maligno.png
# 228maligno.png
# 229maligno.png
# 230maligno.png
# 231maligno.png
# 232maligno.png
# 233maligno.png
# 234maligno.png
# 235maligno.png
# 236maligno.png
# 237maligno.png
# 238maligno.png
# 239maligno.png
# 240maligno.png
# 241maligno.png
# 242maligno.png
# 243maligno.png
# 244maligno.png
# 245maligno.png
# 246maligno.png
# 247maligno.png
# 248maligno.png
# 249maligno.png
# 250maligno.png
# 251maligno.png
# 252maligno.png
# 253maligno.png
# 254maligno.png
# 255maligno.png
# 256maligno.png
# 257maligno.png
# 258maligno.png
# 259maligno.png
# 260maligno.png
# 261maligno.png

# %%
#treating and storing the cropped images

all_cropped_images = [cropped_benigno_images,cropped_maligno_images]
results = [[],[]]
paths = ['/content/drive/MyDrive/BootcampFinal/cropped_and_treated_nods_benigno_pipeline1/','/content/drive/MyDrive/BootcampFinal/cropped_and_treated_nods_maligno_pipeline1/']
group_name = ['benigno','maligno']

for index,group in enumerate(all_cropped_images):
  
  count = 0
  for uni in group:
    
    os.chdir(paths[index])
    myPipe = pre_processing(uni.copy(),to_gray=True)
    myPipe.gaussian_blur((3,3))
    myPipe.fixed_threshold(70,threshold_zero=True)
    #display_img(myPipe.image)
    result = myPipe.image
    #result = pipe.propagation(254)
    #display_img(result)
    #print(str(count)+group_name[index]+'.png')
    #save_image(cv2.imread(result),image_name=str(count)+group_name[index]+'.png')
    cv2.imwrite(str(count)+group_name[index]+'.png',np.array(result))
    count+=1
